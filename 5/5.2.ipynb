# %%
# %matplotlib ipympl

from sympy import *
from sympy.plotting import plot3d, plot
import matplotlib.pyplot as plt
import numpy as np

x, y = symbols("x y")

# %%
def task(f, xlim, ylim):
    sols = solve(Eq(f, 0), (x, y))
    for sol in sols:
        if x in sol:
            plt.axhline(sol[1], color='g', label=f"y={sol[1]}")
        if y in sol:
            plt.axvline(sol[0], color='r', label=f"x={sol[0]}")
    
    sols = solveset(Eq(f, 0), x)
    print("Нули x")
    display(sols)

    sols = solveset(Eq(f, 0), y)
    print("Нули y")
    display(sols)

    plt.title("при n=0")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.legend()
    plt.xlim((xlim[0], xlim[1]))
    plt.ylim((ylim[0], ylim[1]))

    plot3d(f, (x, xlim[0], xlim[1]), (y, ylim[0], ylim[1]))

# %%
f = x * (y - 5) ** 2
task(f, (-5, 5), (0, 10))
# Out:
# Нули x
# {0}
# Нули y
# {5}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f = (y - E/20) ** 2 * sin(pi * x)
task(f, (-2, 2), (-1, 1))
# Out:
# Нули x
# Union(ImageSet(Lambda(_n, 2*_n), Integers), ImageSet(Lambda(_n, (2*_n*pi + pi)/pi), Integers))
# Нули y
# {E/20}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f = x * sin(x) * sin(y - 2)
task(f, (-2*np.pi, 2*np.pi), (-2*np.pi, 2*np.pi))
# Out:
# Нули x
# Union(ImageSet(Lambda(_n, 2*_n*pi), Integers), ImageSet(Lambda(_n, 2*_n*pi + pi), Integers))
# Нули y
# Union(ImageSet(Lambda(_n, 2*_n*pi + 2), Integers), ImageSet(Lambda(_n, 2*_n*pi + 2 + pi), Integers))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# f = 5 * x ** 2 + sin(a * pi) + b
# (1, 8), (2, 4), (15, -3), (6, 7)
